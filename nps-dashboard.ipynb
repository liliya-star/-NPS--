# %% [markdown]
# <img src=https://img.gazeta.ru/files3/923/11732923/dicaprio-pic905-895x505-13209.jpg><br>
# <hr style="border: 10px solid green;" />
#
# ## <span style="color:green">Финальный комментарий<span>
# Спасибо за проделанную работу🤝
#
# Лилия, спасибо за доработки, всё принято👌
#
# Желаю дальнейших успехов и отличного настроения🖐 В качестве бонуса, рекомендую, отличную книгу про оформление презентаций, графиков - [Александр Богачев, Графики, которые убеждают](https://ru.bookmate.com/books/pfLCYNJM) и можно заглянуть в канал и сайт [Ромы Бунина](https://t.me/revealthedata) (кажется, главный человек по визуализации в Росии😉)
#
#
# Поздравляю, проект принят👍

# %% [markdown]
# <hr style="border: 2px solid green;" />
#
# ## Комментарий ревьювера
#
# Лилия, Привет!
#
# 🤚Меня зовут, Олег Юрьев, я буду проверять твой проект. Если не против, я буду обращаться к тебе на _ТЫ_ . Если это неприемлемо, обязательно напиши мне в комментариях - мы перейдем на _ВЫ_ .
#
# 🤝Спасибо, что сдала проект вовремя. Тобой проделана большая работа, молодец!
#
# ✏️В этой тетрадке ты найдешь мои комментарии.
#
# Комментарии будут выделены:
#
# <div style="border-radius: 15px; box-shadow: 4px 4px 4px; border: solid green 2px; padding: 20px"> <b>Отличная работа ✅</b><br>
#     Безупречная работа</div>
# <br>
# <div style="border-radius: 15px; box-shadow: 4px 4px 4px; border: solid orange 2px; padding: 20px"> <b>Что можно улучшить ⚠️</b><br>
#     Ничего дорабатывать не надо, данные пункты работают нормально, но есть способы улучшить. Несколько таких комментариев допустимы, но более - придется некоторые доработать. Большое кол-во мелких замечаний и помарок сказываются на общем впечатлении от работы.</div>
# <br>
# <div style="border-radius: 15px; box-shadow: 4px 4px 4px; border: solid red 2px; padding: 20px"> <b>Что необходимо доработать ⛔️</b><br>
#     Такие пункты необходимо исправить в первую очередь, чтобы я смог принять проект.</div>
#
# Не удаляй комментарии, так будем следить за динамикой 📈
#
# Давай будем в диалоге - основные цели в диалоге:
# - обмен опытом (да я тоже учусь у студентов👨‍🎓)
# - выполнить проект еще лучше
# - помочь тебе стать аналитиком
#
# Поэтому чтобы мне проще было проверять повторно, а тебе контролировать процесс ревью, оставляй свои комментарии и выделяй их.
#
# <div class="alert alert-info" style="border:solid blue 2px; padding: 20px"> <b>Комментарий студента:</b> Например, вот так.</div>
#
# Поехали! :)
#
# <hr style="border: 2px solid green;" />

# %% [markdown]
# <div class="alert alert-info">Анализ текущего уровня потребительской лояльности по результатам NPS-опросов

# %% [markdown]
# Заказчик этого исследования — большая телекоммуникационная компания, которая оказывает услуги на территории всего СНГ. Перед компанией стоит задача определить текущий уровень потребительской лояльности, или NPS (от англ. Net Promoter Score), среди клиентов из России. Чтобы определить уровень лояльности, клиентам задавали классический вопрос: «Оцените по шкале от 1 до 10 вероятность того, что вы порекомендуете компанию друзьям и знакомым». Данные выгрузили в SQLite
#
# Для целей исследования построим дашборд, который представит информацию о текущем уровне NPS среди клиентов и покажет, как этот уровень меняется в зависимости от пользовательских признаков.

# %%
import pandas as pd
import numpy as np

from sqlalchemy import create_engine

# %% [markdown]
# <div class="alert alert-info">Подключаемся к базе данных

# %%
path_to_db = '/datasets/telecomm_csi.db'
engine = create_engine(f'sqlite:///{path_to_db}', echo = False)

# %% [markdown]
# <div class="alert alert-info">Сохраняем данные в датафрейм. Учтем сразу наличие пропусков в age age_segment, удалим эти строки, так акк их количество не большое и значительного влияние не окажет

# %%
#query = """
#SELECT * FROM location;
#"""

# %%
query = """
SELECT u.user_id,
       u.lt_day,
       CASE
           WHEN u.lt_day <= 365 THEN 'новый'
           WHEN u.lt_day > 365 THEN 'старый'
       END AS is_new,
       age,
       CASE
           WHEN u.gender_segment == 0 THEN 'мужчина'
           WHEN u.gender_segment == 1 THEN 'женщина'
       END AS gender_segment,
       u.os_name,
       u.cpe_type_name,
       l.country,
       l.city,
       SUBSTR(a_s.title, 4, 8) AS age_segment,
       SUBSTR(t_s.title, 4, 8) AS traffic_segment,
       SUBSTR(l_s.title, 4, 8) AS lifetime_segment,
       u.nps_score,
       CASE
           WHEN u.nps_score >= 9 THEN 'сторонники'
           WHEN u.nps_score == 7 OR nps_score ==8 THEN 'нейтралы'
           WHEN u.nps_score < 7 THEN 'критики'
       END AS nps_group
FROM user AS u
LEFT JOIN location AS l ON u.location_id=l.location_id
LEFT JOIN age_segment AS a_s ON u.age_gr_id=a_s.age_gr_id
LEFT JOIN traffic_segment AS t_s ON u.tr_gr_id=t_s.tr_gr_id
LEFT JOIN lifetime_segment AS l_s ON u.lt_gr_id=l_s.lt_gr_id
WHERE age IS NOT NULL AND gender_segment IS NOT NULL;
"""

# %%
df = pd.read_sql(query, engine)
df.head(10)
# Out:
#   user_id  lt_day  is_new   age gender_segment  os_name cpe_type_name country  \
# 0  A001A2    2320  старый  45.0        женщина  ANDROID    SMARTPHONE  Россия
# 1  A001WF    2344  старый  53.0        мужчина  ANDROID    SMARTPHONE  Россия
# 2  A003Q7     467  старый  57.0        мужчина  ANDROID    SMARTPHONE  Россия
# 3  A004TB    4190  старый  44.0        женщина      IOS    SMARTPHONE  Россия
# 4  A004XT    1163  старый  24.0        мужчина  ANDROID    SMARTPHONE  Россия
# 5  A005O0    5501  старый  42.0        женщина  ANDROID    SMARTPHONE  Россия
# 6  A0061R    1236  старый  45.0        мужчина  ANDROID    SMARTPHONE  Россия
# 7  A009KS     313   новый  35.0        мужчина  ANDROID    SMARTPHONE  Россия
# 8  A00AES    3238  старый  36.0        женщина  ANDROID    SMARTPHONE  Россия
# 9  A00F70    4479  старый  54.0        женщина  ANDROID    SMARTPHONE  Россия
#
#              city age_segment traffic_segment lifetime_segment  nps_score  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501152 entries, 0 to 501151
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   user_id           501152 non-null  object
#  1   lt_day            501152 non-null  int64
#  2   is_new            501152 non-null  object
#  3   age               501152 non-null  float64
#  4   gender_segment    501152 non-null  object
#  5   os_name           501152 non-null  object
#  6   cpe_type_name     501152 non-null  object
#  7   country           501152 non-null  object
#  8   city              501152 non-null  object
#  9   age_segment       501152 non-null  object
#  10  traffic_segment   501152 non-null  object
#  11  lifetime_segment  501152 non-null  object
#  12  nps_score         501152 non-null  int64
#  13  nps_group         501152 non-null  object
# dtypes: float64(1), int64(2), object(11)
# memory usage: 53.5+ MB

# %%
df.to_csv('telecomm_csi_tableau.csv', index=False)

# %% [markdown]
# ### Укажите ссылку на дашборд на сайте Tableau Public:

# %% [markdown]
# https://public.tableau.com/app/profile/liliy4269/viz/project2_16743192457890/sheet1#1

# %% [markdown]
# ### Укажите ссылку на pdf-файл с презентацией:

# %% [markdown]
# https://disk.yandex.ru/i/R8ZCjtYx_W5STw

# %% [markdown]
# <div style="border-radius: 15px; box-shadow: 4px 4px 4px; border: solid green 2px; padding: 20px">
#
# ## Общий комментарий
# Спасибо за проделанную работу🤝
#
# Лилия, ниже комментарии по разделам проекта:
#
# **Pipeline**
#
# ✅ SQL запрос написан корректно, молодец
#
#
# ----------------------
# **Dash**
#
# В целом дашборд выполнен очень хорошо, могу рекомендовать только улучшения:
# - 💡 _Распределение участников опроса по городам_ - графики по городам лучше повернуть, чтобы названия городов можно было прочитать
# - 💡 график _Распределение NPS по возрасту_ лучше использовать сортировку по возрастным группам, так будет видна зависимость с _ростом возраста ...._ или можно использовать [combination plot](https://youtu.be/L2oolkmhKL8)
# - будет классно добавить индикатор _Кол-во респондентов_ рядом с индикатором NPS
#
# Нашлась единственная доработка:
# - 🔴 опубликовать только дашборд - [video](https://youtu.be/iKNbpYqQNCc)
#
# ----------------------
# **Slides**
#
# 🔴Доработки:
# - слайд 4 - не обязательно "впихнуть всё в один слайд" можно разбить на 2-3. Как, минимум так проще воспринимать информацию
# - NPS по городам - всё же рекомендую скорректировать график, так чтобы на презентации он читался. Например, на дашборде могут быть много городов (например, 20-30-50), но для презентации они не важны, важнее, чтобы то, что есть читалось. Например, топ-5\10, но читаемых со слайда
#
#
# Вот за это _Однако, тут важно учесть, что 3 из 4х характеристик
# представляют собой самые малочисленные
# группы опрошенных и вряд ли такой клиент будет
# интересен в качестве целевой аудитории._ - отдельное спасибо, мало кто обращает на это внимание😎
#
# 💡 Возможно стоит подкорректировать заголовки слайдов:
# - должны всегда быть
# - одного размера
# - в одном и том же месте, когда они сдвигаются это ухудшает читаеость со слайда
#
#
# Исправляй и отправляй на проверку🛠
